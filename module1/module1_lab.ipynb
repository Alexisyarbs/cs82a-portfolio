# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
import pandas as pd
pd.DataFrame({"week":[1], "status":["ready"]})
# Out:
#    week status
# 0     1  ready

# %% [markdown]
# You can use AI to help debug any errors in your code, but you must log your prompts. You cannot submit AI answers for anything meant to be written in your own words.
